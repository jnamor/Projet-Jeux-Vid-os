# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("C:/Users/namor/Dropbox/Simplon/Programmation/Pandas/Projet Groupe/Video_Games_Sales_as_at_22_Dec_2016.csv", sep=",")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Les NaN sont très embetantes, car elles rendent le dataframe inexploitable par morceau. Il faut s'en debarasser

# %%
# Pour connaitre le nombres de NaN par colonnes
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
# Trouver les lignes avec des NaN
index_with_nan = df.index[df.isnull().any(axis=1)]

# Supprimer les lignes avec des NaN
df.drop(index_with_nan,0, inplace=True)

# %%
df.isna().sum()
# Out:
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %%
df.describe()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      6825.000000  6825.000000  6825.000000  6825.000000  6825.000000
# mean       2007.436777     0.394484     0.236089     0.064158     0.082677
# std           4.211248     0.967385     0.687330     0.287570     0.269871
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2011.000000     0.390000     0.210000     0.010000     0.070000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count    User_Count
# count   6825.000000   6825.000000   6825.000000   6825.000000
# mean       0.777590     70.272088     28.931136    174.722344
# std        1.963443     13.868572     19.224165    587.428538
# ...

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
df.groupby(['Global_Sales', 'User_Score']).Year_of_Release.count()
# Out:
# Global_Sales  User_Score
# 0.01          2.1           1
#               2.3           1
#               2.4           1
#               3             1
#               3.1           2
#                            ..
# 28.92         6.6           1
# 29.80         8.5           1
# 32.77         8             1
# 35.52         8.3           1
# 82.53         8             1
# Name: Year_of_Release, Length: 4003, dtype: int64

# %%
df[(df['Year_of_Release'] == 2006.0) & (df['Global_Sales'] > 5.0)]
# Out:
#                                        Name Platform  Year_of_Release  \
# 0                                Wii Sports      Wii           2006.0
# 6                     New Super Mario Bros.       DS           2006.0
# 7                                  Wii Play      Wii           2006.0
# 107  The Legend of Zelda: Twilight Princess      Wii           2006.0
# 142                            Gears of War     X360           2006.0
# 148                       Final Fantasy XII      PS2           2006.0
# 156                            Cooking Mama       DS           2006.0
# 196                          Guitar Hero II      PS2           2006.0
# 204     Grand Theft Auto: Vice City Stories      PSP           2006.0
#
#             Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0          Sports                Nintendo     41.36     28.96      3.77
# 6        Platform                Nintendo     11.28      9.14      6.50
# ...

# %%
df.groupby('Year_of_Release')[['Global_Sales']].mean()
# Out:
#                  Global_Sales
# Year_of_Release
# 1985.0               0.030000
# 1988.0               0.030000
# 1992.0               0.030000
# 1994.0               1.270000
# 1996.0               2.871429
# 1997.0               2.693077
# 1998.0               1.727200
# 1999.0               1.705667
# 2000.0               0.796471
# 2001.0               0.991719
# 2002.0               0.634813
# 2003.0               0.512751
# 2004.0               0.676008
# 2005.0               0.594875
# 2006.0               0.789242
# 2007.0               0.773271
# 2008.0               0.826216
# 2009.0               0.836091
# 2010.0               0.962611
# 2011.0               0.846998
# 2012.0               0.932684
# 2013.0               1.004398
# 2014.0               0.760593
# 2015.0               0.754313
# 2016.0               0.431887

# %%
data=df[['Year_of_Release', 'Global_Sales']].mean()
plt.figure(figsize=(20,5))
sns.barplot(x=df.Year_of_Release,y=df.Global_Sales, data=data)
plt.xlabel("Année de sortie")
plt.ylabel("Ventes mondiales")

# 
# plt.title('Les prix des produits',size='large')
# save plot
# plt.savefig('plot/fig1.jpg')
# Out:
# Text(0, 0.5, 'Ventes mondiales')

# %%
data_1 = df.groupby('Genre')[['Global_Sales']].mean()
plt.figure(figsize=(20,5))
sns.barplot(x=df.Global_Sales,y=df.Genre, data=data_1)
plt.xlabel("Ventes mondiales")
plt.ylabel("Genre")
# Out:
# Text(0, 0.5, 'Genre')

# %%
data_2 = df.groupby('Platform')[['Global_Sales']].mean()
plt.figure(figsize=(20,5))
sns.barplot(x=df.Global_Sales,y=df.Platform, data=data_2)
plt.xlabel("Ventes mondiales")
plt.ylabel("Plateformes")
# Out:
# Text(0, 0.5, 'Plateformes')

# %%
data_2.plot.pie(subplots=True, autopct="%.1f%%", figsize=(10, 10), )
plt.ylabel('Ventes mondiales')
# Out:
# Text(0, 0.5, 'Ventes mondiales')

# %%
data_3 = df[['User_Score','Global_Sales']].drop_duplicates()
plt.figure(figsize=(25,15))
sns.swarmplot(x=data_3.User_Score, y=data_3.Global_Sales)
plt.title("Disponibilité de produit avec stock",size='large')
# Out:
# C:\Users\namor\anaconda3\envs\intro-conda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 78.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\namor\anaconda3\envs\intro-conda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 78.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\namor\anaconda3\envs\intro-conda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 79.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\namor\anaconda3\envs\intro-conda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 77.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import matplotlib.pyplot as plt

def pred_a(x):
    a=1
    b=-10
    f=[]
    for elem in x:
        f.append(a*elem+b)
    return f

#Pour tracer les predictions taille des enfants selon la taille des parents xl
xl=[0.1, 40]

fig = plt.figure(figsize=(14,10))
plt.plot(df.User_Score,df.Global_Sales,'+',c='blue',label='observations (Ventes globables, Score utilisateur)')
plt.plot(xl,pred_a(xl),c='green',label='Mon prédicteur')
plt.xlabel('Score utilisateur', fontsize=14)
plt.ylabel('Ventes globables', fontsize=14)
plt.xlim(xl)
plt.ylim(xl)
plt.legend()
plt.show()

# %%
fig = sns.lmplot(x='NA_Sales', y='EU_Sales', data=data_4)
plt.xlabel('Ventes en Amérique', fontsize=14)
plt.ylabel('Ventes en Europe', fontsize=14)
# Out:
# Text(6.799999999999997, 0.5, 'Ventes en Europe')

# %%
fig = sns.lmplot(x='Global_Sales', y='NA_Sales', hue='Platform', data=df)
plt.xlabel('Ventes en Amérique', fontsize=14)
plt.ylabel('Ventes en Europe', fontsize=14)
# Out:
# Text(12.103819444444447, 0.5, 'Ventes en Europe')

# %%
# Prédire Global_Sales en fonction des ventes américaines et européennes
data_4 = df[['Platform', 'NA_Sales', 'EU_Sales', 'Global_Sales']] 
data_4 = data_4.groupby(['Platform']).mean()
data_4
# Out:
#           NA_Sales  EU_Sales  Global_Sales
# Platform
# 3DS       0.314000  0.215032      0.795032
# DC        0.110000  0.020714      0.325000
# DS        0.373707  0.205388      0.823987
# GBA       0.334979  0.137553      0.555907
# GC        0.310144  0.088879      0.458103
# PC        0.097942  0.161014      0.287435
# PS        0.611733  0.430533      1.377000
# PS2       0.414605  0.223807      0.829798
# PS3       0.444239  0.355657      1.019896
# PS4       0.352134  0.467699      1.016862
# PSP       0.209487  0.125974      0.481846
# PSV       0.084153  0.074322      0.261695
# Wii       0.715887  0.426159      1.375741
# WiiU      0.344831  0.229438      0.742472
# X360      0.621713  0.273112      0.994522
# XB        0.271204  0.088920      0.375345
# XOne      0.475346  0.264277      0.814906

# %%
fig2 = sns.catplot(x="Global_Sales",  data=df, kind='count')

# %%
import matplotlib.pyplot as plt

def pred_a(x):
    a=0.6
    b=0.01
    f=[]
    for elem in x:
        f.append(a*elem+b)
    return f

#Pour tracer les predictions taille des enfants selon la taille des parents xl
xl=[0.01, 10]

fig = plt.figure(figsize=(14,10))
plt.plot(df.Global_Sales,df.NA_Sales,'+',c='blue',label='Observations (Ventes globables, Score utilisateur)')
plt.plot(xl,pred_a(xl),c='green',label='Mon prédicteur')
plt.xlabel('Ventes mondiales', fontsize=14)
plt.ylabel('Ventes en Amérique', fontsize=14)
plt.xlim(xl)
plt.ylim(xl)
plt.legend()
plt.show()

# %%
x=df['Global_Sales']
y=df['NA_Sales']

# %%
# Exemple calcul d'une fonction implementation d'une fonction somme et equivalence pandas
tmp=0
for i in range(len(x)):
    tmp=tmp+x[i]*y[i]
print(tmp,(df['Global_Sales']*df['NA_Sales']).sum())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\intro-conda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-322-60c90e2c326e> in <module>
#       2 tmp=0
# ...

# %%
# Calcul des membres principaux de la solution a et b
# Puis calcul du a


un=len(x)*(df['Global_Sales']*df['NA_Sales']).sum()

sumx=df['Global_Sales'].sum()
sumy=df['NA_Sales'].sum()

deux=len(df['Global_Sales'])*((df['Global_Sales']*df['Global_Sales']).sum())

trois=sumx*sumx

a=(un-(sumx*sumy))/(deux-trois)
a
# Out:
# 0.4709179580473479

# %%
# Puis calcul du b
quatre=sumy*((df['Global_Sales']*df['Global_Sales']).sum())
cinq=sumx*(df['Global_Sales']*df['NA_Sales']).sum()
six=len(df['Global_Sales'])*((df['Global_Sales']*df['Global_Sales']).sum())
sept=sumx*sumx

b=(quatre-cinq)/(six-sept)
b
# Out:
# 0.028302542233673598

# %%
a=0.4709179580473479
b=0.028302542233673598

def pred(x,a,b):
    return a*x+b

pred(150,a,b)
# Out:
# 70.66599624933586

# %%
import math

est_p=[pred(i,a,b) for i in x]
est_pa=pred_a(x) 

print("RMSE du meilleur predicteur selon moindre carré",math.sqrt(((pd.Series(est_p)-df['NA_Sales'])**2).sum()/len(df)))
print("RMSE du predicteur identifié analytiquement", math.sqrt(((pd.Series(est_pa)-df['NA_Sales'])**2).sum()/len(df)))
# Out:
# RMSE du meilleur predicteur selon moindre carré 0.3453389904832611
# RMSE du predicteur identifié analytiquement 0.3192345928541036

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(df['NA_Sales'], est_p))
print(rmse)
# Out:
# 0.284428339767731

# %%
def rmse(data_x,data_y):
    i = 0
    res = 0
    
    for i in range(len(data_x)):
              
        res += ((nouv_prediction_pere(data_x[i])-data_y[i])**2)/len(data_x)
    
    return math.sqrt(res)


def nouv_prediction_pere(x):
    a = 0.4709179580473479
    b = 0.028302542233673598
    return a*x+b
